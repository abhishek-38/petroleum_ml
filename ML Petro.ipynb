# %%
import pandas as pd

# %%
df = pd.read_excel('Volve_production_data.xlsx')

# %%
df
# Out:
#          DATEPRD  WELL_BORE_CODE  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  \
# 0     2014-04-07   NO 15/9-F-1 C                7405         15/9-F-1 C
# 1     2014-04-08   NO 15/9-F-1 C                7405         15/9-F-1 C
# 2     2014-04-09   NO 15/9-F-1 C                7405         15/9-F-1 C
# 3     2014-04-10   NO 15/9-F-1 C                7405         15/9-F-1 C
# 4     2014-04-11   NO 15/9-F-1 C                7405         15/9-F-1 C
# ...          ...             ...                 ...                ...
# 15629 2016-09-14  NO 15/9-F-5 AH                5769           15/9-F-5
# 15630 2016-09-15  NO 15/9-F-5 AH                5769           15/9-F-5
# 15631 2016-09-16  NO 15/9-F-5 AH                5769           15/9-F-5
# 15632 2016-09-17  NO 15/9-F-5 AH                5769           15/9-F-5
# 15633 2016-09-18  NO 15/9-F-5 AH                5769           15/9-F-5
#
#        NPD_FIELD_CODE NPD_FIELD_NAME  NPD_FACILITY_CODE NPD_FACILITY_NAME  \
# 0             3420717          VOLVE             369304    MÆRSK INSPIRER
# 1             3420717          VOLVE             369304    MÆRSK INSPIRER
# 2             3420717          VOLVE             369304    MÆRSK INSPIRER
# 3             3420717          VOLVE             369304    MÆRSK INSPIRER
# 4             3420717          VOLVE             369304    MÆRSK INSPIRER
# ...               ...            ...                ...               ...
# 15629         3420717          VOLVE             369304    MÆRSK INSPIRER
# 15630         3420717          VOLVE             369304    MÆRSK INSPIRER
# 15631         3420717          VOLVE             369304    MÆRSK INSPIRER
# 15632         3420717          VOLVE             369304    MÆRSK INSPIRER
# 15633         3420717          VOLVE             369304    MÆRSK INSPIRER
#
#        ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  ...  AVG_CHOKE_UOM  AVG_WHP_P  \
# 0                0.0                0.00000  ...              %    0.00000
# 1                0.0                    NaN  ...              %    0.00000
# 2                0.0                    NaN  ...              %    0.00000
# 3                0.0                    NaN  ...              %    0.00000
# 4                0.0              310.37614  ...              %   33.09788
# ...              ...                    ...  ...            ...        ...
# 15629            0.0                    NaN  ...              %    0.07776
# 15630            0.0                    NaN  ...              %    0.08545
# 15631            0.0                    NaN  ...              %    0.08544
# 15632            0.0                    NaN  ...              %    0.07497
# 15633            0.0                    NaN  ...            NaN        NaN
#
#        AVG_WHT_P  DP_CHOKE_SIZE BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 0        0.00000        0.00000          0.0           0.0           0.0
# 1        0.00000        0.00000          0.0           0.0           0.0
# 2        0.00000        0.00000          0.0           0.0           0.0
# 3        0.00000        0.00000          0.0           0.0           0.0
# 4       10.47992       33.07195          0.0           0.0           0.0
# ...          ...            ...          ...           ...           ...
# 15629    0.22879        0.01862          0.0           0.0           0.0
# 15630    0.22914        0.00631          0.0           0.0           0.0
# 15631    0.22896        0.01181          0.0           0.0           0.0
# 15632    0.22846        0.02576          0.0           0.0           0.0
# 15633        NaN        0.00000          NaN           NaN           NaN
#
#        BORE_WI_VOL   FLOW_KIND  WELL_TYPE
# 0              NaN  production         WI
# 1              NaN  production         OP
# 2              NaN  production         OP
# 3              NaN  production         OP
# 4              NaN  production         OP
# ...            ...         ...        ...
# 15629          NaN  production         OP
# 15630          NaN  production         OP
# 15631          NaN  production         OP
# 15632          NaN  production         OP
# 15633          0.0   injection         WI
#
# [15634 rows x 24 columns]

# %%
df.head(5)
# Out:
#      DATEPRD WELL_BORE_CODE  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  \
# 0 2014-04-07  NO 15/9-F-1 C                7405         15/9-F-1 C
# 1 2014-04-08  NO 15/9-F-1 C                7405         15/9-F-1 C
# 2 2014-04-09  NO 15/9-F-1 C                7405         15/9-F-1 C
# 3 2014-04-10  NO 15/9-F-1 C                7405         15/9-F-1 C
# 4 2014-04-11  NO 15/9-F-1 C                7405         15/9-F-1 C
#
#    NPD_FIELD_CODE NPD_FIELD_NAME  NPD_FACILITY_CODE NPD_FACILITY_NAME  \
# 0         3420717          VOLVE             369304    MÆRSK INSPIRER
# 1         3420717          VOLVE             369304    MÆRSK INSPIRER
# 2         3420717          VOLVE             369304    MÆRSK INSPIRER
# 3         3420717          VOLVE             369304    MÆRSK INSPIRER
# 4         3420717          VOLVE             369304    MÆRSK INSPIRER
#
#    ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  ...  AVG_CHOKE_UOM  AVG_WHP_P  \
# 0            0.0                0.00000  ...              %    0.00000
# 1            0.0                    NaN  ...              %    0.00000
# 2            0.0                    NaN  ...              %    0.00000
# 3            0.0                    NaN  ...              %    0.00000
# 4            0.0              310.37614  ...              %   33.09788
#
#    AVG_WHT_P  DP_CHOKE_SIZE BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 0    0.00000        0.00000          0.0           0.0           0.0
# 1    0.00000        0.00000          0.0           0.0           0.0
# 2    0.00000        0.00000          0.0           0.0           0.0
# 3    0.00000        0.00000          0.0           0.0           0.0
# 4   10.47992       33.07195          0.0           0.0           0.0
#
#    BORE_WI_VOL   FLOW_KIND  WELL_TYPE
# 0          NaN  production         WI
# 1          NaN  production         OP
# 2          NaN  production         OP
# 3          NaN  production         OP
# 4          NaN  production         OP
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['DATEPRD', 'WELL_BORE_CODE', 'NPD_WELL_BORE_CODE', 'NPD_WELL_BORE_NAME',
#        'NPD_FIELD_CODE', 'NPD_FIELD_NAME', 'NPD_FACILITY_CODE',
#        'NPD_FACILITY_NAME', 'ON_STREAM_HRS', 'AVG_DOWNHOLE_PRESSURE',
#        'AVG_DOWNHOLE_TEMPERATURE', 'AVG_DP_TUBING', 'AVG_ANNULUS_PRESS',
#        'AVG_CHOKE_SIZE_P', 'AVG_CHOKE_UOM', 'AVG_WHP_P', 'AVG_WHT_P',
#        'DP_CHOKE_SIZE', 'BORE_OIL_VOL', 'BORE_GAS_VOL', 'BORE_WAT_VOL',
#        'BORE_WI_VOL', 'FLOW_KIND', 'WELL_TYPE'],
#       dtype='object')

# %%
df.shape
print ("number of rows - %d" %(df.shape[0]))
print ("number of columns - %d" %(df.shape[1]))
# Out:
# number of rows - 15634
# number of columns - 24

# %%
df['WELL_TYPE'].unique()
# Out:
# array(['WI', 'OP'], dtype=object)

# %%
df['NPD_WELL_BORE_NAME'].unique()
# Out:
# array(['15/9-F-1 C', '15/9-F-11', '15/9-F-12', '15/9-F-14', '15/9-F-15 D',
#        '15/9-F-4', '15/9-F-5'], dtype=object)

# %%
wellA = df[df.NPD_WELL_BORE_NAME == "15/9-F-1 C"]

wellA.shape
# Out:
# (746, 24)

# %%
wellA.head(5)
# Out:
#      DATEPRD WELL_BORE_CODE  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  \
# 0 2014-04-07  NO 15/9-F-1 C                7405         15/9-F-1 C
# 1 2014-04-08  NO 15/9-F-1 C                7405         15/9-F-1 C
# 2 2014-04-09  NO 15/9-F-1 C                7405         15/9-F-1 C
# 3 2014-04-10  NO 15/9-F-1 C                7405         15/9-F-1 C
# 4 2014-04-11  NO 15/9-F-1 C                7405         15/9-F-1 C
#
#    NPD_FIELD_CODE NPD_FIELD_NAME  NPD_FACILITY_CODE NPD_FACILITY_NAME  \
# 0         3420717          VOLVE             369304    MÆRSK INSPIRER
# 1         3420717          VOLVE             369304    MÆRSK INSPIRER
# 2         3420717          VOLVE             369304    MÆRSK INSPIRER
# 3         3420717          VOLVE             369304    MÆRSK INSPIRER
# 4         3420717          VOLVE             369304    MÆRSK INSPIRER
#
#    ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  ...  AVG_CHOKE_UOM  AVG_WHP_P  \
# 0            0.0                0.00000  ...              %    0.00000
# 1            0.0                    NaN  ...              %    0.00000
# 2            0.0                    NaN  ...              %    0.00000
# 3            0.0                    NaN  ...              %    0.00000
# 4            0.0              310.37614  ...              %   33.09788
#
#    AVG_WHT_P  DP_CHOKE_SIZE BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 0    0.00000        0.00000          0.0           0.0           0.0
# 1    0.00000        0.00000          0.0           0.0           0.0
# 2    0.00000        0.00000          0.0           0.0           0.0
# 3    0.00000        0.00000          0.0           0.0           0.0
# 4   10.47992       33.07195          0.0           0.0           0.0
#
#    BORE_WI_VOL   FLOW_KIND  WELL_TYPE
# 0          NaN  production         WI
# 1          NaN  production         OP
# 2          NaN  production         OP
# 3          NaN  production         OP
# 4          NaN  production         OP
#
# [5 rows x 24 columns]

# %%
wellA.drop("BORE_WAT_VOL", axis = 1)
wellA.drop("NPD_FIELD_NAME", axis = 1)
# Out:
#        DATEPRD WELL_BORE_CODE  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  \
# 0   2014-04-07  NO 15/9-F-1 C                7405         15/9-F-1 C
# 1   2014-04-08  NO 15/9-F-1 C                7405         15/9-F-1 C
# 2   2014-04-09  NO 15/9-F-1 C                7405         15/9-F-1 C
# 3   2014-04-10  NO 15/9-F-1 C                7405         15/9-F-1 C
# 4   2014-04-11  NO 15/9-F-1 C                7405         15/9-F-1 C
# ..         ...            ...                 ...                ...
# 741 2016-04-17  NO 15/9-F-1 C                7405         15/9-F-1 C
# 742 2016-04-18  NO 15/9-F-1 C                7405         15/9-F-1 C
# 743 2016-04-19  NO 15/9-F-1 C                7405         15/9-F-1 C
# 744 2016-04-20  NO 15/9-F-1 C                7405         15/9-F-1 C
# 745 2016-04-21  NO 15/9-F-1 C                7405         15/9-F-1 C
#
#      NPD_FIELD_CODE  NPD_FACILITY_CODE NPD_FACILITY_NAME  ON_STREAM_HRS  \
# 0           3420717             369304    MÆRSK INSPIRER            0.0
# 1           3420717             369304    MÆRSK INSPIRER            0.0
# 2           3420717             369304    MÆRSK INSPIRER            0.0
# 3           3420717             369304    MÆRSK INSPIRER            0.0
# 4           3420717             369304    MÆRSK INSPIRER            0.0
# ..              ...                ...               ...            ...
# 741         3420717             369304    MÆRSK INSPIRER            0.0
# 742         3420717             369304    MÆRSK INSPIRER            0.0
# 743         3420717             369304    MÆRSK INSPIRER            0.0
# 744         3420717             369304    MÆRSK INSPIRER            0.0
# 745         3420717             369304    MÆRSK INSPIRER            0.0
#
#      AVG_DOWNHOLE_PRESSURE  AVG_DOWNHOLE_TEMPERATURE  ...  AVG_CHOKE_UOM  \
# 0                  0.00000                   0.00000  ...              %
# 1                      NaN                       NaN  ...              %
# 2                      NaN                       NaN  ...              %
# 3                      NaN                       NaN  ...              %
# 4                310.37614                  96.87589  ...              %
# ..                     ...                       ...  ...            ...
# 741              270.26849                 101.19807  ...              %
# 742              276.86895                 101.23102  ...              %
# 743              282.10538                 101.17754  ...              %
# 744              285.09577                 101.13142  ...              %
# 745                0.00000                   0.00000  ...              %
#
#      AVG_WHP_P  AVG_WHT_P DP_CHOKE_SIZE  BORE_OIL_VOL  BORE_GAS_VOL  \
# 0      0.00000    0.00000       0.00000           0.0           0.0
# 1      0.00000    0.00000       0.00000           0.0           0.0
# 2      0.00000    0.00000       0.00000           0.0           0.0
# 3      0.00000    0.00000       0.00000           0.0           0.0
# 4     33.09788   10.47992      33.07195           0.0           0.0
# ..         ...        ...           ...           ...           ...
# 741    6.49814    9.80247       2.64528           0.0           0.0
# 742   13.71397   11.74224       4.12000           0.0           0.0
# 743    8.57579   10.11906       1.86628           0.0           0.0
# 744   18.28026    9.87213       7.41391           0.0           0.0
# 745    0.00000    0.00000       0.00000           0.0           0.0
#
#      BORE_WAT_VOL  BORE_WI_VOL   FLOW_KIND  WELL_TYPE
# 0             0.0          NaN  production         WI
# 1             0.0          NaN  production         OP
# 2             0.0          NaN  production         OP
# 3             0.0          NaN  production         OP
# 4             0.0          NaN  production         OP
# ..            ...          ...         ...        ...
# 741           0.0          NaN  production         OP
# 742           0.0          NaN  production         OP
# 743           0.0          NaN  production         OP
# 744           0.0          NaN  production         OP
# 745           0.0          NaN  production         OP
#
# [746 rows x 23 columns]

# %%
wellA.isna().any(axis = 0)
# Out:
# DATEPRD                     False
# WELL_BORE_CODE              False
# NPD_WELL_BORE_CODE          False
# NPD_WELL_BORE_NAME          False
# NPD_FIELD_CODE              False
# NPD_FIELD_NAME              False
# NPD_FACILITY_CODE           False
# NPD_FACILITY_NAME           False
# ON_STREAM_HRS               False
# AVG_DOWNHOLE_PRESSURE        True
# AVG_DOWNHOLE_TEMPERATURE     True
# AVG_DP_TUBING                True
# AVG_ANNULUS_PRESS            True
# AVG_CHOKE_SIZE_P            False
# AVG_CHOKE_UOM               False
# AVG_WHP_P                   False
# AVG_WHT_P                   False
# DP_CHOKE_SIZE               False
# BORE_OIL_VOL                False
# BORE_GAS_VOL                False
# BORE_WAT_VOL                False
# BORE_WI_VOL                  True
# FLOW_KIND                   False
# WELL_TYPE                   False
# dtype: bool

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (20,10))
plt.title("Production History for Well 15/9-F-1 C", fontsize = 35, color= "purple")
wellA.set_index("DATEPRD").BORE_OIL_VOL.rolling(30).mean().plot(fontsize = 20)
# Out:
# <AxesSubplot:title={'center':'Production History for Well 15/9-F-1 C'}, xlabel='DATEPRD'>

# %%
wellA.set_index("DATEPRD").resample('M').sum().plot(y = "BORE_OIL_VOL", figsize = (15,10),fontsize = 20)

plt.ylabel('Cummulative Production', fontsize = 20)
plt.xlabel('Date', fontsize = 20)

plt.title("Monthly Production History",fontsize = 25)

plt.show()

# %%
import seaborn as sns

# %%
df = pd.read_excel('Volve_production_data.xlsx',sheet_name='Daily Production Data')

# %%
df.head(5)
# Out:
#      DATEPRD WELL_BORE_CODE  NPD_WELL_BORE_CODE NPD_WELL_BORE_NAME  \
# 0 2014-04-07  NO 15/9-F-1 C                7405         15/9-F-1 C
# 1 2014-04-08  NO 15/9-F-1 C                7405         15/9-F-1 C
# 2 2014-04-09  NO 15/9-F-1 C                7405         15/9-F-1 C
# 3 2014-04-10  NO 15/9-F-1 C                7405         15/9-F-1 C
# 4 2014-04-11  NO 15/9-F-1 C                7405         15/9-F-1 C
#
#    NPD_FIELD_CODE NPD_FIELD_NAME  NPD_FACILITY_CODE NPD_FACILITY_NAME  \
# 0         3420717          VOLVE             369304    MÆRSK INSPIRER
# 1         3420717          VOLVE             369304    MÆRSK INSPIRER
# 2         3420717          VOLVE             369304    MÆRSK INSPIRER
# 3         3420717          VOLVE             369304    MÆRSK INSPIRER
# 4         3420717          VOLVE             369304    MÆRSK INSPIRER
#
#    ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  ...  AVG_CHOKE_UOM  AVG_WHP_P  \
# 0            0.0                0.00000  ...              %    0.00000
# 1            0.0                    NaN  ...              %    0.00000
# 2            0.0                    NaN  ...              %    0.00000
# 3            0.0                    NaN  ...              %    0.00000
# 4            0.0              310.37614  ...              %   33.09788
#
#    AVG_WHT_P  DP_CHOKE_SIZE BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 0    0.00000        0.00000          0.0           0.0           0.0
# 1    0.00000        0.00000          0.0           0.0           0.0
# 2    0.00000        0.00000          0.0           0.0           0.0
# 3    0.00000        0.00000          0.0           0.0           0.0
# 4   10.47992       33.07195          0.0           0.0           0.0
#
#    BORE_WI_VOL   FLOW_KIND  WELL_TYPE
# 0          NaN  production         WI
# 1          NaN  production         OP
# 2          NaN  production         OP
# 3          NaN  production         OP
# 4          NaN  production         OP
#
# [5 rows x 24 columns]

# %%
df = df[["DATEPRD","NPD_WELL_BORE_NAME","ON_STREAM_HRS","AVG_DOWNHOLE_PRESSURE","AVG_DOWNHOLE_TEMPERATURE","BORE_OIL_VOL","BORE_GAS_VOL","BORE_WAT_VOL","FLOW_KIND"]]

# %%
wellA = df[df.NPD_WELL_BORE_NAME == "15/9-F-1 C"]

# %%
wellA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 746 entries, 0 to 745
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   DATEPRD                   746 non-null    datetime64[ns]
#  1   NPD_WELL_BORE_NAME        746 non-null    object
#  2   ON_STREAM_HRS             746 non-null    float64
#  3   AVG_DOWNHOLE_PRESSURE     743 non-null    float64
#  4   AVG_DOWNHOLE_TEMPERATURE  743 non-null    float64
#  5   BORE_OIL_VOL              746 non-null    float64
#  6   BORE_GAS_VOL              746 non-null    float64
#  7   BORE_WAT_VOL              746 non-null    float64
#  8   FLOW_KIND                 746 non-null    object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 58.3+ KB

# %%
wellA.isna().any(axis = 0)
# Out:
# DATEPRD                     False
# NPD_WELL_BORE_NAME          False
# ON_STREAM_HRS               False
# AVG_DOWNHOLE_PRESSURE        True
# AVG_DOWNHOLE_TEMPERATURE     True
# BORE_OIL_VOL                False
# BORE_GAS_VOL                False
# BORE_WAT_VOL                False
# FLOW_KIND                   False
# dtype: bool

# %%
wellA.columns[wellA.isna().any(axis = 0)]
wellA.isna().any(axis = 1)
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 741    False
# 742    False
# 743    False
# 744    False
# 745    False
# Length: 746, dtype: bool

# %%
wellA[wellA.isna().any(axis = 1)]
# Out:
#      DATEPRD NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 1 2014-04-08         15/9-F-1 C            0.0                    NaN
# 2 2014-04-09         15/9-F-1 C            0.0                    NaN
# 3 2014-04-10         15/9-F-1 C            0.0                    NaN
#
#    AVG_DOWNHOLE_TEMPERATURE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 1                       NaN           0.0           0.0           0.0
# 2                       NaN           0.0           0.0           0.0
# 3                       NaN           0.0           0.0           0.0
#
#     FLOW_KIND
# 1  production
# 2  production
# 3  production

# %%
wellA1 = wellA.dropna() ## by default inplace=False to make the drop temporary unless assigned to a new dataframe
wellA1.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0 2014-04-07         15/9-F-1 C            0.0                0.00000
# 4 2014-04-11         15/9-F-1 C            0.0              310.37614
# 5 2014-04-12         15/9-F-1 C            0.0              303.50078
# 6 2014-04-13         15/9-F-1 C            0.0              303.53481
# 7 2014-04-14         15/9-F-1 C            0.0              303.78228
#
#    AVG_DOWNHOLE_TEMPERATURE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 0                   0.00000           0.0           0.0           0.0
# 4                  96.87589           0.0           0.0           0.0
# 5                  96.92339           0.0           0.0           0.0
# 6                  96.95885           0.0           0.0           0.0
# 7                  96.96873           0.0           0.0           0.0
#
#     FLOW_KIND
# 0  production
# 4  production
# 5  production
# 6  production
# 7  production

# %%
wellA1.iloc[[1],1:5]
# Out:
#   NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 4         15/9-F-1 C            0.0              310.37614
#
#    AVG_DOWNHOLE_TEMPERATURE
# 4                  96.87589

# %%
wellA1.loc[[4],"NPD_WELL_BORE_NAME":"AVG_DOWNHOLE_TEMPERATURE"] ### what if you type 1
# Out:
#   NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 4         15/9-F-1 C            0.0              310.37614
#
#    AVG_DOWNHOLE_TEMPERATURE
# 4                  96.87589

# %%
wellA2 = wellA.dropna(axis = 1)
wellA2.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME  ON_STREAM_HRS  BORE_OIL_VOL  BORE_GAS_VOL  \
# 0 2014-04-07         15/9-F-1 C            0.0           0.0           0.0
# 1 2014-04-08         15/9-F-1 C            0.0           0.0           0.0
# 2 2014-04-09         15/9-F-1 C            0.0           0.0           0.0
# 3 2014-04-10         15/9-F-1 C            0.0           0.0           0.0
# 4 2014-04-11         15/9-F-1 C            0.0           0.0           0.0
#
#    BORE_WAT_VOL   FLOW_KIND
# 0           0.0  production
# 1           0.0  production
# 2           0.0  production
# 3           0.0  production
# 4           0.0  production

# %%
wellA4 = wellA.fillna(wellA.mean())
wellA4.head()
# Out:
# <ipython-input-31-2e514b7a5189>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   wellA4 = wellA.fillna(wellA.mean())
#      DATEPRD NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0 2014-04-07         15/9-F-1 C            0.0               0.000000
# 1 2014-04-08         15/9-F-1 C            0.0             246.666033
# 2 2014-04-09         15/9-F-1 C            0.0             246.666033
# 3 2014-04-10         15/9-F-1 C            0.0             246.666033
# 4 2014-04-11         15/9-F-1 C            0.0             310.376140
#
#    AVG_DOWNHOLE_TEMPERATURE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 0                  0.000000           0.0           0.0           0.0
# 1                104.925294           0.0           0.0           0.0
# 2                104.925294           0.0           0.0           0.0
# 3                104.925294           0.0           0.0           0.0
# 4                 96.875890           0.0           0.0           0.0
#
#     FLOW_KIND
# 0  production
# 1  production
# 2  production
# 3  production
# 4  production

# %%
wellA5 = wellA.fillna(wellA.median())
wellA5.head()
# Out:
# <ipython-input-32-c0ae6c740db7>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   wellA5 = wellA.fillna(wellA.median())
#      DATEPRD NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0 2014-04-07         15/9-F-1 C            0.0               0.000000
# 1 2014-04-08         15/9-F-1 C            0.0             240.637585
# 2 2014-04-09         15/9-F-1 C            0.0             240.637585
# 3 2014-04-10         15/9-F-1 C            0.0             240.637585
# 4 2014-04-11         15/9-F-1 C            0.0             310.376140
#
#    AVG_DOWNHOLE_TEMPERATURE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 0                  0.000000           0.0           0.0           0.0
# 1                107.820459           0.0           0.0           0.0
# 2                107.820459           0.0           0.0           0.0
# 3                107.820459           0.0           0.0           0.0
# 4                 96.875890           0.0           0.0           0.0
#
#     FLOW_KIND
# 0  production
# 1  production
# 2  production
# 3  production
# 4  production

# %%
wellA.drop("BORE_WAT_VOL", axis = 1) ## inplace = False .. so the drop is not permanent
# Out:
#        DATEPRD NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0   2014-04-07         15/9-F-1 C            0.0                0.00000
# 1   2014-04-08         15/9-F-1 C            0.0                    NaN
# 2   2014-04-09         15/9-F-1 C            0.0                    NaN
# 3   2014-04-10         15/9-F-1 C            0.0                    NaN
# 4   2014-04-11         15/9-F-1 C            0.0              310.37614
# ..         ...                ...            ...                    ...
# 741 2016-04-17         15/9-F-1 C            0.0              270.26849
# 742 2016-04-18         15/9-F-1 C            0.0              276.86895
# 743 2016-04-19         15/9-F-1 C            0.0              282.10538
# 744 2016-04-20         15/9-F-1 C            0.0              285.09577
# 745 2016-04-21         15/9-F-1 C            0.0                0.00000
#
#      AVG_DOWNHOLE_TEMPERATURE  BORE_OIL_VOL  BORE_GAS_VOL   FLOW_KIND
# 0                     0.00000           0.0           0.0  production
# 1                         NaN           0.0           0.0  production
# 2                         NaN           0.0           0.0  production
# 3                         NaN           0.0           0.0  production
# 4                    96.87589           0.0           0.0  production
# ..                        ...           ...           ...         ...
# 741                 101.19807           0.0           0.0  production
# 742                 101.23102           0.0           0.0  production
# 743                 101.17754           0.0           0.0  production
# 744                 101.13142           0.0           0.0  production
# 745                   0.00000           0.0           0.0  production
#
# [746 rows x 8 columns]

# %%
wellA1["DATEPRD"] = pd.to_datetime(wellA1.DATEPRD)
# Out:
# <ipython-input-34-c3f1db188c5c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wellA1["DATEPRD"] = pd.to_datetime(wellA1.DATEPRD)

# %%
wellA1.DATEPRD.dt.year
# Out:
# 0      2014
# 4      2014
# 5      2014
# 6      2014
# 7      2014
#        ...
# 741    2016
# 742    2016
# 743    2016
# 744    2016
# 745    2016
# Name: DATEPRD, Length: 743, dtype: int64

# %%
wellA1["year"] = wellA1.DATEPRD.dt.year

wellA1["month"] = wellA1.DATEPRD.dt.month
# Out:
# <ipython-input-37-d686d8310d99>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wellA1["year"] = wellA1.DATEPRD.dt.year
# <ipython-input-37-d686d8310d99>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wellA1["month"] = wellA1.DATEPRD.dt.month

# %%
wellA1.head()
# Out:
#      DATEPRD NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# 0 2014-04-07         15/9-F-1 C            0.0                0.00000
# 4 2014-04-11         15/9-F-1 C            0.0              310.37614
# 5 2014-04-12         15/9-F-1 C            0.0              303.50078
# 6 2014-04-13         15/9-F-1 C            0.0              303.53481
# 7 2014-04-14         15/9-F-1 C            0.0              303.78228
#
#    AVG_DOWNHOLE_TEMPERATURE  BORE_OIL_VOL  BORE_GAS_VOL  BORE_WAT_VOL  \
# 0                   0.00000           0.0           0.0           0.0
# 4                  96.87589           0.0           0.0           0.0
# 5                  96.92339           0.0           0.0           0.0
# 6                  96.95885           0.0           0.0           0.0
# 7                  96.96873           0.0           0.0           0.0
#
#     FLOW_KIND  year  month
# 0  production  2014      4
# 4  production  2014      4
# 5  production  2014      4
# 6  production  2014      4
# 7  production  2014      4

# %%
wellA1["month"] = wellA1.month.map({1:"January", 2:"February", 3: "March",
                   4: "April", 5: "May", 6: "June",
                   7: "July", 8: "August", 9: "Septemeber",
                   10: "October", 11:"November", 12: "December"})
# Out:
# <ipython-input-39-9274d4e5705c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wellA1["month"] = wellA1.month.map({1:"January", 2:"February", 3: "March",

# %%
productionData = df[df.FLOW_KIND == "production"]

# %%
# Create Year Column from Date Time Object
productionData["DATEPRD"] = pd.to_datetime(productionData["DATEPRD"])
productionData["YEAR"] = productionData["DATEPRD"].dt.year
# Out:
# <ipython-input-45-2852b2f5e864>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   productionData["DATEPRD"] = pd.to_datetime(productionData["DATEPRD"])
# <ipython-input-45-2852b2f5e864>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   productionData["YEAR"] = productionData["DATEPRD"].dt.year

# %%
productionData.groupby("NPD_WELL_BORE_NAME").sum()
# Out:
#                     ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# NPD_WELL_BORE_NAME
# 15/9-F-1 C             9983.53315          183272.862798
# 15/9-F-11             26006.21614          271162.380252
# 15/9-F-12             65204.06928          246223.670095
# 15/9-F-14             62773.67519          710877.683553
# 15/9-F-15 D           17824.83278          221062.144637
# 15/9-F-5               2973.32502               0.000000
#
#                     AVG_DOWNHOLE_TEMPERATURE  BORE_OIL_VOL  BORE_GAS_VOL  \
# NPD_WELL_BORE_NAME
# 15/9-F-1 C                      77959.493534     177709.33  2.644092e+07
# 15/9-F-11                      120921.733869    1147849.10  1.743105e+08
# 15/9-F-12                      101540.832797    4579609.55  6.675423e+08
# 15/9-F-14                      290158.064528    3942233.39  5.780095e+08
# 15/9-F-15 D                    102343.339583     148518.56  2.250535e+07
# 15/9-F-5                            0.000000      41160.68  6.561826e+06
#
#                     BORE_WAT_VOL     YEAR
# NPD_WELL_BORE_NAME
# 15/9-F-1 C             207302.39  1503033
# 15/9-F-11             1090806.27  2347021
# 15/9-F-12             6833320.37  6148466
# 15/9-F-14             7121249.74  6148466
# 15/9-F-15 D             52366.40  1970579
# 15/9-F-5                13533.18   322560

# %%
fig, ax = plt.subplots(figsize = (20,10))

productionData.groupby("NPD_WELL_BORE_NAME").sum().plot.pie(ax = ax, y = "BORE_OIL_VOL", figsize = (20,10), fontsize = 13)

ax.set_ylabel("")

ax.legend(fontsize = 11, loc = 3)

plt.show()

# %%
wellA1.set_index('DATEPRD',inplace=True) # make date the index
wellA1.head()
# Out:
#            NPD_WELL_BORE_NAME  ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# DATEPRD
# 2014-04-07         15/9-F-1 C            0.0                0.00000
# 2014-04-11         15/9-F-1 C            0.0              310.37614
# 2014-04-12         15/9-F-1 C            0.0              303.50078
# 2014-04-13         15/9-F-1 C            0.0              303.53481
# 2014-04-14         15/9-F-1 C            0.0              303.78228
#
#             AVG_DOWNHOLE_TEMPERATURE  BORE_OIL_VOL  BORE_GAS_VOL  \
# DATEPRD
# 2014-04-07                   0.00000           0.0           0.0
# 2014-04-11                  96.87589           0.0           0.0
# 2014-04-12                  96.92339           0.0           0.0
# 2014-04-13                  96.95885           0.0           0.0
# 2014-04-14                  96.96873           0.0           0.0
#
#             BORE_WAT_VOL   FLOW_KIND  year  month
# DATEPRD
# 2014-04-07           0.0  production  2014  April
# 2014-04-11           0.0  production  2014  April
# 2014-04-12           0.0  production  2014  April
# 2014-04-13           0.0  production  2014  April
# 2014-04-14           0.0  production  2014  April

# %%
corr_matrix = wellA1.corr(method = "spearman")

# %%
corr_matrix
# Out:
#                           ON_STREAM_HRS  AVG_DOWNHOLE_PRESSURE  \
# ON_STREAM_HRS                  1.000000              -0.680431
# AVG_DOWNHOLE_PRESSURE         -0.680431               1.000000
# AVG_DOWNHOLE_TEMPERATURE       0.867190              -0.803018
# BORE_OIL_VOL                   0.900021              -0.712879
# BORE_GAS_VOL                   0.900609              -0.714979
# BORE_WAT_VOL                   0.824137              -0.467589
# year                          -0.256166               0.358382
#
#                           AVG_DOWNHOLE_TEMPERATURE  BORE_OIL_VOL  \
# ON_STREAM_HRS                             0.867190      0.900021
# AVG_DOWNHOLE_PRESSURE                    -0.803018     -0.712879
# AVG_DOWNHOLE_TEMPERATURE                  1.000000      0.758801
# BORE_OIL_VOL                              0.758801      1.000000
# BORE_GAS_VOL                              0.760886      0.998843
# BORE_WAT_VOL                              0.769345      0.624659
# year                                     -0.298393     -0.372121
#
#                           BORE_GAS_VOL  BORE_WAT_VOL      year
# ON_STREAM_HRS                 0.900609      0.824137 -0.256166
# AVG_DOWNHOLE_PRESSURE        -0.714979     -0.467589  0.358382
# AVG_DOWNHOLE_TEMPERATURE      0.760886      0.769345 -0.298393
# BORE_OIL_VOL                  0.998843      0.624659 -0.372121
# BORE_GAS_VOL                  1.000000      0.627614 -0.368445
# BORE_WAT_VOL                  0.627614      1.000000  0.115113
# year                         -0.368445      0.115113  1.000000

# %%
# Removing the repeated section of the correlation matrix
mask = np.zeros_like(corr_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
mask
# Out:
# <ipython-input-52-fbf54e34cdb1>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr_matrix, dtype=np.bool)
# array([[ True,  True,  True,  True,  True,  True,  True],
#        [False,  True,  True,  True,  True,  True,  True],
#        [False, False,  True,  True,  True,  True,  True],
#        [False, False, False,  True,  True,  True,  True],
#        [False, False, False, False,  True,  True,  True],
#        [False, False, False, False, False,  True,  True],
#        [False, False, False, False, False, False,  True]])

# %%
# Create Axis
fig, ax = plt.subplots(figsize=(12, 12))

# Using Seaborn HeatMap
sns.heatmap(corr_matrix, mask = mask, square = True, linewidths = .8, cbar_kws = {'shrink': .4,  'ticks' : [-1, -.5, 0, 0.5, 1]},
            cmap = 'coolwarm', vmin = -1,  vmax = 1, annot = True, annot_kws = {'size': 14})

# Setting Axis Properties
ax.set_yticklabels(corr_matrix.columns, rotation = 0, size = 15)
ax.set_xticklabels(corr_matrix.columns, rotation = 90, size =15)
ax.set_title("Correlation Matrix", size = 25)

sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

# %%
plt.figure(figsize = (20,10))

wellA1.AVG_DOWNHOLE_PRESSURE.plot(kind = "hist",bins=20)

plt.title("Distribution of Downhole Pressure in Well 15/9 F-1 C", fontsize = 20)

plt.ylabel("Frequency", fontsize = 20)

plt.xlabel("Average Downhole Pressure", fontsize = 20)

plt.xticks(fontsize = 15)

plt.yticks(fontsize = 15)

plt.show()

# %%
import seaborn as sns

sns.set(style="white", color_codes=True)

#tips = sns.load_dataset("tips")

g = sns.jointplot(x="BORE_OIL_VOL", y="AVG_DOWNHOLE_PRESSURE", data=wellA1)

# %%
plt.figure(figsize = (20,10))

sns.set(font_scale = 2)
sns.violinplot(x = "year", y = "AVG_DOWNHOLE_PRESSURE", data = wellA1)

plt.title("AVERAGE DOWNHOLE PRESSURE BY YEAR", fontsize = 35)
# Out:
# Text(0.5, 1.0, 'AVERAGE DOWNHOLE PRESSURE BY YEAR')

# %%
plt.figure(figsize = (20,10))

sns.violinplot(x = "year", y = "AVG_DOWNHOLE_TEMPERATURE", data = wellA1)

plt.title("AVERAGE TEMPERATURE BY YEAR", fontsize = 25)
# Out:
# Text(0.5, 1.0, 'AVERAGE TEMPERATURE BY YEAR')

# %%
#Using Seaborn 
plt.figure(figsize = (20,10))

sns.boxplot(x = "year", y = "BORE_OIL_VOL", data = wellA1)

plt.title("AVERAGE DOWNHOLE PRESSURE BY YEAR using Seaborn", fontsize = 35)
# Out:
# Text(0.5, 1.0, 'AVERAGE DOWNHOLE PRESSURE BY YEAR using Seaborn')

# %%
#Using Pandas Plot Method

pd.pivot(wellA1, values = "AVG_DOWNHOLE_PRESSURE", columns = "year").boxplot(figsize = (20,10), fontsize = 15)

plt.title("AVERAGE DOWNHOLE PRESSURE BY YEAR using Pandas Plot", fontsize = 25)

plt.ylabel("Pressure", fontsize = 15)
# Out:
# Text(0, 0.5, 'Pressure')

# %%
#Load data
well_13 = pd.read_excel('VolveData_Project.xlsx', sheet_name='well 13',index_col=0)
well_14 = pd.read_excel('VolveData_Project.xlsx', sheet_name='well 14')
well_15 = pd.read_excel('VolveData_Project.xlsx', sheet_name='well 15')

# %%
data = pd.concat([well_14, well_15], axis=0)
data['Well'] = data['Well'].astype('category')
data['RT_log'] = np.log10(data.RT) #For Visualization
data
# Out:
#        Depth Well       GR      RT    RHOB    NPHI Facies    RT_log
# 0     3178.5   14  50.2190  0.5888  2.3296  0.3657     SH -0.230032
# 1     3179.0   14  47.2468  0.7768  2.3170  0.3776     UN -0.109691
# 2     3179.5   14  49.5247  1.0707  2.2960  0.5390     SH  0.029668
# 3     3180.0   14  44.9124  1.4460  2.2514  0.5482     UN  0.160168
# 4     3180.5   14  47.0048  0.9542  2.2733  0.5076     UN -0.020361
# ...      ...  ...      ...     ...     ...     ...    ...       ...
# 1154  4083.5   15  59.7060  1.7590  2.4851  0.1416     CB  0.245266
# 1155  4084.0   15  58.4170  1.6510  2.4860  0.1416     CB  0.217747
# 1156  4084.5   15  57.4990  1.5970  2.5311  0.1527     CB  0.203305
# 1157  4085.0   15  56.7850  1.4820  2.4731  0.1785     CB  0.170848
# 1158  4085.5   15  61.7220  1.4350  2.4920  0.1566     CB  0.156852
#
# [3241 rows x 8 columns]

# %%
sns.pairplot(data.drop(['Well','Depth'], axis = 1) ,hue='Facies',diag_kind='hist')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import seaborn as sns
import numpy as np
import time

from mpl_toolkits.axes_grid1 import make_axes_locatable
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import IsolationForest, RandomForestClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
labels = [1,2,3,4] 
data['Facies_Label']=np.select([data['Facies'] == 'SH',
                                data['Facies'] == 'UN',
                                data['Facies'] == 'SS',
                                data['Facies'] == 'CB',]
                                ,labels)

# %%
data
# Out:
#        Depth Well       GR      RT    RHOB    NPHI Facies    RT_log  \
# 0     3178.5   14  50.2190  0.5888  2.3296  0.3657     SH -0.230032
# 1     3179.0   14  47.2468  0.7768  2.3170  0.3776     UN -0.109691
# 2     3179.5   14  49.5247  1.0707  2.2960  0.5390     SH  0.029668
# 3     3180.0   14  44.9124  1.4460  2.2514  0.5482     UN  0.160168
# 4     3180.5   14  47.0048  0.9542  2.2733  0.5076     UN -0.020361
# ...      ...  ...      ...     ...     ...     ...    ...       ...
# 1154  4083.5   15  59.7060  1.7590  2.4851  0.1416     CB  0.245266
# 1155  4084.0   15  58.4170  1.6510  2.4860  0.1416     CB  0.217747
# 1156  4084.5   15  57.4990  1.5970  2.5311  0.1527     CB  0.203305
# 1157  4085.0   15  56.7850  1.4820  2.4731  0.1785     CB  0.170848
# 1158  4085.5   15  61.7220  1.4350  2.4920  0.1566     CB  0.156852
#
#       Facies_Label
# 0                1
# 1                2
# 2                1
# 3                2
# 4                2
# ...            ...
# 1154             4
# 1155             4
# 1156             4
# 1157             4
# 1158             4
#
# [3241 rows x 9 columns]

# %%
facies_colors = ['#2E86C1', '#196F3D','#F4D03F','#DC7633']

facies = ['SH', 'UN', 'SS', 'CB']

def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster=np.repeat(np.expand_dims(logs['Facies_Label'].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=5, figsize=(8, 12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.RT_log, logs.Depth, '-')
    ax[2].plot(logs.NPHI, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.RHOB, logs.Depth, '-', color='r')
    im=ax[4].imshow(cluster, interpolation='none', aspect='auto',
                   cmap=cmap_facies,vmin=1,vmax=4)
    
    divider = make_axes_locatable(ax[4])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((50*' ').join(['SH', 'UN', 'SS', 'CB']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("RT")
    ax[1].set_xlim(logs.RT_log.min(),logs.RT_log.max())
    ax[2].set_xlabel("NPHI")
    ax[2].set_xlim(logs.NPHI.min(),logs.NPHI.max())
    ax[3].set_xlabel("RHOB")
    ax[3].set_xlim(logs.RHOB.min(),logs.RHOB.max())
    ax[4].set_xlabel('Facies')
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([]); ax[4].set_yticklabels([])
    ax[4].set_xticklabels([])
    f.suptitle('Well: %s'%logs.iloc[0]['Well'], fontsize=14,y=0.94)

# %%
make_facies_log_plot(data[data['Well'] == 14],facies_colors)

# %%
#Bar chart: Distribution of Facies
Facies_dist = data['Facies'].value_counts().sort_index()

Facies_dist.plot(kind='bar',color=facies_colors, 
                   title='Distribution of Facies')
# Out:
# <AxesSubplot:title={'center':'Distribution of Facies'}>

# %%
#Setting Depth as Index for marking purpose
data.set_index('Depth',inplace=True)

#
data.groupby("Well").count()

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 3241 entries, 3178.5 to 4085.5
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Well          3241 non-null   category
#  1   GR            3241 non-null   float64
#  2   RT            3241 non-null   float64
#  3   RHOB          3241 non-null   float64
#  4   NPHI          3241 non-null   float64
#  5   Facies        3241 non-null   object
#  6   RT_log        3241 non-null   float64
#  7   Facies_Label  3241 non-null   int32
# dtypes: category(1), float64(5), int32(1), object(1)
# memory usage: 193.2+ KB

# %%
data.describe()
# Out:
#                 GR           RT         RHOB         NPHI       RT_log  \
# count  3241.000000  3241.000000  3241.000000  3241.000000  3241.000000
# mean     51.379917     4.292569     2.432688     0.207456     0.278370
# std      57.700965    14.524740     0.147662     0.104241     0.487116
# min       3.655000     0.094000     1.805100     0.013500    -1.026872
# 25%      17.433000     1.014000     2.311000     0.133600     0.006038
# 50%      34.083600     1.864900     2.459000     0.187900     0.270656
# 75%      71.846000     3.697700     2.550000     0.267500     0.567932
# max    1567.590000   461.170000     3.149300     0.853200     2.663861
#
#        Facies_Label
# count   3241.000000
# mean       2.809627
# std        1.209471
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000

# %%
X = data.drop(['Facies','Well','Facies_Label','RT_log'], axis = 1) #Features: Feature vector
y = data['Facies']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1000)
print('Dimensions of X_train:',X_train.shape)
print('Dimensions of X_test:',X_test.shape)
# Out:
# Dimensions of X_train: (2268, 4)
# Dimensions of X_test: (973, 4)

# %%
X_train.hist()
plt.show()

# %%
X_test
# Out:
#               GR      RT    RHOB    NPHI
# Depth
# 3281.0   51.3597  0.6210  2.1899  0.3108
# 4217.5  102.8300  0.9319  2.6062  0.1316
# 3640.0   32.3120  2.8370  2.6359  0.1477
# 4152.5   21.3774  0.2730  2.2880  0.1866
# 4088.0   22.1788  0.3589  2.2902  0.1883
# ...          ...     ...     ...     ...
# 3699.5  184.3600  1.0980  2.2141  0.3384
# 3822.5  154.8366  2.2770  2.3451  0.3593
# 3789.0   84.9310  1.7140  2.4610  0.2864
# 4210.0   79.4283  2.0538  2.4910  0.1103
# 3916.0   35.2000  6.8630  2.2461  0.1976
#
# [973 rows x 4 columns]

# %%
X_train
# Out:
#               GR       RT    RHOB    NPHI
# Depth
# 3958.0   96.8273   1.4131  2.4470  0.2886
# 3350.0   29.4533   0.3319  2.1855  0.2314
# 3469.0    5.9483   7.0130  2.6040  0.0642
# 3885.5  125.7879   1.4531  2.4600  0.3380
# 3867.0   22.9630  89.0210  2.1741  0.1930
# ...          ...      ...     ...     ...
# 3865.5  122.0454   1.3979  2.4603  0.2360
# 3663.0   56.6610   1.9690  2.5258  0.1803
# 3518.5   14.9110   2.0960  2.5109  0.1396
# 3479.0   14.5110   3.2803  2.5780  0.1076
# 3909.0  108.3635   1.3439  2.4510  0.3031
#
# [2268 rows x 4 columns]

# %%
# Robust Scaler
rscaler = RobustScaler() #instantiate
rscaler.fit(X_train)
# Out:
# RobustScaler()

# %%
X_train_scaled = rscaler.transform(X_train) # transform the train dataset to standardized data

# Original training dataset
print("Original median : %s " % rscaler.center_)
print("Original IQR : %s " % rscaler.scale_)

#Scaled training dataset
print("Scaled median : %s " % np.median(X_train_scaled,axis=0))
print("Scaled IQR : %s " % (np.percentile(X_train_scaled, 75,axis=0)-np.percentile(X_train_scaled, 25,axis=0)))
# Out:
# Original median : [33.7498  1.8525  2.458   0.1876]
# Original IQR : [50.22925   2.7383    0.23975   0.131825]
# Scaled median : [0. 0. 0. 0.]
# Scaled IQR : [1. 1. 1. 1.]

# %%
#Scale the test data using the parameters learnt from the training dataset
X_test_scaled  = rscaler.transform(X_test)

print("Median of scaled test data: %s" % np.median(X_test_scaled,axis=0))
print("IQR of scaled test data: %s " % (np.percentile(X_test_scaled, 75,axis=0)-np.percentile(X_test_scaled, 25,axis=0)))
# Out:
# Median of scaled test data: [0.02342858 0.01150349 0.00834202 0.00758581]
# IQR of scaled test data: [1.24073722 0.92243363 0.98435871 1.06125545]

# %%
pd.DataFrame(X_train_scaled,index=X_train.index, columns=X_test.columns).hist()
plt.show()

# %%
X_train=pd.DataFrame(X_train_scaled,index=X_train.index, columns=X_test.columns)
X_test=pd.DataFrame(X_test_scaled,index=X_test.index, columns=X_test.columns)
X_test
# Out:
#               GR        RT      RHOB      NPHI
# Depth
# 3281.0  0.350591 -0.449732 -1.118248  0.934572
# 4217.5  1.375298 -0.336194  0.618144 -0.424806
# 3640.0 -0.028625  0.359530  0.742023 -0.302674
# 4152.5 -0.246319 -0.576818 -0.709072 -0.007586
# 4088.0 -0.230364 -0.545448 -0.699896  0.005310
# ...          ...       ...       ...       ...
# 3699.5  2.998456 -0.275536 -1.017310  1.143941
# 3822.5  2.410683  0.155023 -0.470907  1.302484
# 3789.0  1.018952 -0.050579  0.012513  0.749478
# 4210.0  0.909400  0.073513  0.137643 -0.586383
# 3916.0  0.028872  1.829785 -0.883837  0.075858
#
# [973 rows x 4 columns]

# %%
# Isolation Forest
iforest = IsolationForest(n_estimators=200, contamination=0.5/100)
iforest = iforest.fit(X_train) #Training the model

# %%
#Predictions
X_train_predict = iforest.predict(X_train) 
X_train['Predict']=X_train_predict
X_train['Predict'] = X_train['Predict'].astype('category')
X_train
# Out:
#               GR         RT      RHOB      NPHI Predict
# Depth
# 3958.0  1.255792  -0.160465 -0.045881  0.766167       1
# 3350.0 -0.085538  -0.555308 -1.136601  0.332259       1
# 3469.0 -0.553492   1.884563  0.608968 -0.936090       1
# 3885.5  1.832361  -0.145857  0.008342  1.140907       1
# 3867.0 -0.214751  31.833072 -1.184150  0.040963       1
# ...          ...        ...       ...       ...     ...
# 3865.5  1.757852  -0.166015  0.009593  0.367153       1
# 3663.0  0.456133   0.042545  0.282795 -0.055376       1
# 3518.5 -0.375056   0.088924  0.220647 -0.364119       1
# 3479.0 -0.383020   0.521418  0.500521 -0.606865       1
# 3909.0  1.485463  -0.185736 -0.029197  0.876162       1
#
# [2268 rows x 5 columns]

# %%
#Visualization
sns.pairplot(X_train,hue='Predict',diag_kind='hist')

# %%
#Removing Outliers
X_train['y_train']=y_train
X_train = X_train[X_train['Predict'] == 1]

y_train=X_train['y_train']
X_train = X_train.drop(['Predict','y_train'], axis = 1)

# %%
print(len(X_train))
print(len(y_train))
# Out:
# 2256
# 2256

# %%
#Visualization Without Outliers
sns.pairplot(X_train,diag_kind='hist')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable
import seaborn as sns
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import IsolationForest, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, recall_score, precision_score, classification_report, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
#Load data
well_13 = pd.read_excel('VolveData_Project.xlsx', sheet_name='well 13',index_col=0)
well_14 = pd.read_excel('VolveData_Project.xlsx', sheet_name='well 14')
well_15 = pd.read_excel('VolveData_Project.xlsx', sheet_name='well 15')

# %%
data = pd.concat([well_14, well_15], axis=0)
data['Well'] = data['Well'].astype('category')
data['RT_log'] = np.log10(data.RT) #For Visualization
data
# Out:
#        Depth Well       GR      RT    RHOB    NPHI Facies    RT_log
# 0     3178.5   14  50.2190  0.5888  2.3296  0.3657     SH -0.230032
# 1     3179.0   14  47.2468  0.7768  2.3170  0.3776     UN -0.109691
# 2     3179.5   14  49.5247  1.0707  2.2960  0.5390     SH  0.029668
# 3     3180.0   14  44.9124  1.4460  2.2514  0.5482     UN  0.160168
# 4     3180.5   14  47.0048  0.9542  2.2733  0.5076     UN -0.020361
# ...      ...  ...      ...     ...     ...     ...    ...       ...
# 1154  4083.5   15  59.7060  1.7590  2.4851  0.1416     CB  0.245266
# 1155  4084.0   15  58.4170  1.6510  2.4860  0.1416     CB  0.217747
# 1156  4084.5   15  57.4990  1.5970  2.5311  0.1527     CB  0.203305
# 1157  4085.0   15  56.7850  1.4820  2.4731  0.1785     CB  0.170848
# 1158  4085.5   15  61.7220  1.4350  2.4920  0.1566     CB  0.156852
#
# [3241 rows x 8 columns]

# %%
labels = [1,2,3,4] 
data['Facies_Label']=np.select([data['Facies'] == 'SH',
                                data['Facies'] == 'UN',
                                data['Facies'] == 'SS',
                                data['Facies'] == 'CB',]
                                ,labels)
data.set_index('Depth',inplace=True)
X = data.drop(['Facies','Well','Facies_Label','RT_log'], axis = 1) #Features: Feature vector
y = data['Facies'] #Target: Facies

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1000)
print('Dimensions of X_train:',X_train.shape)
print('Dimensions of X_test:',X_test.shape)
# Out:
# Dimensions of X_train: (2268, 4)
# Dimensions of X_test: (973, 4)

# %%
classifier = LogisticRegression(C=12) 
classifier.fit(X_train, y_train)

print(classifier.coef_) #a1 and a2
print(classifier.intercept_) # a0
# Out:
# [[-0.11112175  0.14385327  2.42030281 -1.34218506]
#  [ 0.10618766  0.11232424 -1.97935433  0.30404147]
#  [-0.05034837  0.15405893  0.53222656  0.9386888 ]
#  [ 0.05528246 -0.41023644 -0.97317504  0.09945479]]
# [-0.4120906  -1.0079555   1.83423451 -0.41418841]

# %%
prediction = classifier.predict(X_test)

# %%
#Compare against true labels (Accuracy)
print('Accuracy (generalization)',classifier.score(X_test,y_test)) #Accuracy (generalization)  
print('Accuracy (memorization)',classifier.score(X_train,y_train)) #Accuracy (memorization)
# Out:
# Accuracy (generalization) 0.7872559095580678
# Accuracy (memorization) 0.7861552028218695

# %%
#Comparing other metrics (f1_score)
print('F1_score (generalization)',f1_score(y_test,classifier.predict(X_test),average="weighted")) #Accuracy (generalization)  
print('F1_score (memorization)',f1_score(y_train,classifier.predict(X_train),average="weighted")) #Accuracy (memorization)
# Out:
# F1_score (generalization) 0.7727171814171544
# F1_score (memorization) 0.7696963599355976

# %%
#Confusion Matrix
names = ['SH', 'UN', 'SS', 'CB']

cf_matrix = confusion_matrix(y_train, classifier.predict(X_train))

cf=sns.heatmap(cf_matrix, annot=True, annot_kws={"size": 12},cmap='Blues',fmt="d",xticklabels=names,yticklabels=names)

plt.show()

# %%
cforest = RandomForestClassifier(criterion='entropy',n_estimators=100,max_depth=5,random_state=1, n_jobs=2) #Creating Instance
cforest.fit(X_train, y_train) #Learning the decision boundaries
y_pred = cforest.predict(X_test)

# %%
#Compare against true labels (Accuracy)
print('Accuracy (generalization)',cforest.score(X_test,y_test)) #Accuracy (generalization)  
print('Accuracy (memorization)',cforest.score(X_train,y_train)) #Accuracy (memorization)
# Out:
# Accuracy (generalization) 0.8766700924974307
# Accuracy (memorization) 0.8959435626102292

# %%
from sklearn.model_selection import GridSearchCV 
  
#Defining parameter range 
Tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
                     'C': [0.1, 1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]},
                    {'kernel': ['poly'],'C': [1, 10, 100, 1000],'degree': [2,3,4]}]
  
svc_mod = GridSearchCV(SVC(), Tuned_parameters, refit = True, verbose = 3)

# %%
svc_mod.fit(X_train, y_train) 
svc_mod.best_estimator_
# Out:
# Fitting 5 folds for each of 41 candidates, totalling 205 fits
# [CV 1/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.3s
# [CV 2/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.3s
# [CV 3/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.2s
# [CV 4/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.2s
# [CV 5/5] END .....................C=0.1, gamma=1, kernel=rbf; total time=   0.3s
# [CV 1/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 2/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 3/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 4/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 5/5] END ...................C=0.1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 1/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV 2/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 3/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV 4/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 1/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 2/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 3/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 4/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 5/5] END .................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 1/5] END ................C=0.1, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV 2/5] END ................C=0.1, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV 3/5] END ................C=0.1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV 4/5] END ................C=0.1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV 5/5] END ................C=0.1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV 1/5] END .......................C=1, gamma=1, kernel=rbf; total time=   0.2s
# [CV 2/5] END .......................C=1, gamma=1, kernel=rbf; total time=   0.3s
# [CV 3/5] END .......................C=1, gamma=1, kernel=rbf; total time=   0.2s
# [CV 4/5] END .......................C=1, gamma=1, kernel=rbf; total time=   0.2s
# [CV 5/5] END .......................C=1, gamma=1, kernel=rbf; total time=   0.3s
# [CV 1/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 2/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 3/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 4/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 5/5] END .....................C=1, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 1/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 2/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 3/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 4/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 5/5] END ....................C=1, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV 1/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 2/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 3/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 4/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=1, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 1/5] END ..................C=1, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV 2/5] END ..................C=1, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV 3/5] END ..................C=1, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV 4/5] END ..................C=1, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV 5/5] END ..................C=1, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV 1/5] END ......................C=10, gamma=1, kernel=rbf; total time=   0.3s
# [CV 2/5] END ......................C=10, gamma=1, kernel=rbf; total time=   0.3s
# [CV 3/5] END ......................C=10, gamma=1, kernel=rbf; total time=   0.3s
# [CV 4/5] END ......................C=10, gamma=1, kernel=rbf; total time=   0.3s
# [CV 5/5] END ......................C=10, gamma=1, kernel=rbf; total time=   0.3s
# [CV 1/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 2/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 3/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 4/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 5/5] END ....................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV 1/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV 2/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 4/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 5/5] END ...................C=10, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV 1/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 2/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 3/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 5/5] END ..................C=10, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 1/5] END .................C=10, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV 2/5] END .................C=10, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV 3/5] END .................C=10, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV 4/5] END .................C=10, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV 5/5] END .................C=10, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV 1/5] END .....................C=100, gamma=1, kernel=rbf; total time=   0.3s
# [CV 2/5] END .....................C=100, gamma=1, kernel=rbf; total time=   0.3s
# [CV 3/5] END .....................C=100, gamma=1, kernel=rbf; total time=   0.2s
# [CV 4/5] END .....................C=100, gamma=1, kernel=rbf; total time=   0.2s
# [CV 5/5] END .....................C=100, gamma=1, kernel=rbf; total time=   0.3s
# [CV 1/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 2/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 3/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 4/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 5/5] END ...................C=100, gamma=0.1, kernel=rbf; total time=   0.1s
# [CV 1/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV 2/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV 3/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV 4/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV 5/5] END ..................C=100, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV 1/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 2/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 3/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV 4/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 5/5] END .................C=100, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 1/5] END ................C=100, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV 2/5] END ................C=100, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV 3/5] END ................C=100, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV 4/5] END ................C=100, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV 5/5] END ................C=100, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV 1/5] END ....................C=1000, gamma=1, kernel=rbf; total time=   0.3s
# [CV 2/5] END ....................C=1000, gamma=1, kernel=rbf; total time=   0.3s
# [CV 3/5] END ....................C=1000, gamma=1, kernel=rbf; total time=   0.3s
# [CV 4/5] END ....................C=1000, gamma=1, kernel=rbf; total time=   0.2s
# [CV 5/5] END ....................C=1000, gamma=1, kernel=rbf; total time=   0.3s
# [CV 1/5] END ..................C=1000, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 2/5] END ..................C=1000, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 3/5] END ..................C=1000, gamma=0.1, kernel=rbf; total time=   0.2s
# [CV 4/5] END ..................C=1000, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 5/5] END ..................C=1000, gamma=0.1, kernel=rbf; total time=   0.3s
# [CV 1/5] END .................C=1000, gamma=0.01, kernel=rbf; total time=   0.1s
# [CV 2/5] END .................C=1000, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV 3/5] END .................C=1000, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV 4/5] END .................C=1000, gamma=0.01, kernel=rbf; total time=   0.2s
# [CV 5/5] END .................C=1000, gamma=0.01, kernel=rbf; total time=   0.3s
# [CV 1/5] END ................C=1000, gamma=0.001, kernel=rbf; total time=   0.2s
# [CV 2/5] END ................C=1000, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 3/5] END ................C=1000, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 4/5] END ................C=1000, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 5/5] END ................C=1000, gamma=0.001, kernel=rbf; total time=   0.1s
# [CV 1/5] END ...............C=1000, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV 2/5] END ...............C=1000, gamma=0.0001, kernel=rbf; total time=   0.0s
# [CV 3/5] END ...............C=1000, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV 4/5] END ...............C=1000, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV 5/5] END ...............C=1000, gamma=0.0001, kernel=rbf; total time=   0.1s
# [CV 1/5] END .............................C=1, kernel=linear; total time=   0.3s
# [CV 2/5] END .............................C=1, kernel=linear; total time=   0.2s
# [CV 3/5] END .............................C=1, kernel=linear; total time=   0.3s
# [CV 4/5] END .............................C=1, kernel=linear; total time=   0.3s
# [CV 5/5] END .............................C=1, kernel=linear; total time=   0.2s
# [CV 1/5] END ............................C=10, kernel=linear; total time=   1.5s
# [CV 2/5] END ............................C=10, kernel=linear; total time=   1.3s
# [CV 3/5] END ............................C=10, kernel=linear; total time=   1.9s
# [CV 4/5] END ............................C=10, kernel=linear; total time=   1.7s
# [CV 5/5] END ............................C=10, kernel=linear; total time=   1.7s
# [CV 1/5] END ...........................C=100, kernel=linear; total time=  11.8s
# [CV 2/5] END ...........................C=100, kernel=linear; total time=   7.8s
# [CV 3/5] END ...........................C=100, kernel=linear; total time=  15.4s
# [CV 4/5] END ...........................C=100, kernel=linear; total time=  11.0s
# [CV 5/5] END ...........................C=100, kernel=linear; total time=  11.2s
# [CV 1/5] END ..........................C=1000, kernel=linear; total time=  47.2s
# [CV 2/5] END ..........................C=1000, kernel=linear; total time=  33.8s
# [CV 3/5] END ..........................C=1000, kernel=linear; total time=  56.7s
# [CV 4/5] END ..........................C=1000, kernel=linear; total time=  45.2s
# [CV 5/5] END ..........................C=1000, kernel=linear; total time=  50.0s
# [CV 1/5] END .....................C=1, degree=2, kernel=poly; total time=   0.0s
# [CV 2/5] END .....................C=1, degree=2, kernel=poly; total time=   0.0s
# [CV 3/5] END .....................C=1, degree=2, kernel=poly; total time=   0.0s
# [CV 4/5] END .....................C=1, degree=2, kernel=poly; total time=   0.0s
# [CV 5/5] END .....................C=1, degree=2, kernel=poly; total time=   0.0s
# [CV 1/5] END .....................C=1, degree=3, kernel=poly; total time=  27.1s
# [CV 2/5] END .....................C=1, degree=3, kernel=poly; total time=   0.0s
# [CV 3/5] END .....................C=1, degree=3, kernel=poly; total time=  12.5s
# [CV 4/5] END .....................C=1, degree=3, kernel=poly; total time=   0.0s
# [CV 5/5] END .....................C=1, degree=3, kernel=poly; total time=   0.0s
# [CV 1/5] END .....................C=1, degree=4, kernel=poly; total time=  11.7s
# [CV 2/5] END .....................C=1, degree=4, kernel=poly; total time=   3.2s
# [CV 3/5] END .....................C=1, degree=4, kernel=poly; total time=   3.3s
# [CV 4/5] END .....................C=1, degree=4, kernel=poly; total time=   0.4s
# [CV 5/5] END .....................C=1, degree=4, kernel=poly; total time=   7.7s
# [CV 1/5] END ....................C=10, degree=2, kernel=poly; total time=   0.0s
# [CV 2/5] END ....................C=10, degree=2, kernel=poly; total time=   0.0s
# [CV 3/5] END ....................C=10, degree=2, kernel=poly; total time=   0.0s
# [CV 4/5] END ....................C=10, degree=2, kernel=poly; total time=   0.0s
# [CV 5/5] END ....................C=10, degree=2, kernel=poly; total time=   0.0s
# [CV 1/5] END ....................C=10, degree=3, kernel=poly; total time=   7.8s
# [CV 2/5] END ....................C=10, degree=3, kernel=poly; total time=   0.0s
# [CV 3/5] END ....................C=10, degree=3, kernel=poly; total time=  11.7s
# [CV 4/5] END ....................C=10, degree=3, kernel=poly; total time=   0.0s
# [CV 5/5] END ....................C=10, degree=3, kernel=poly; total time=   0.1s
# [CV 1/5] END ....................C=10, degree=4, kernel=poly; total time=   1.0s
# [CV 2/5] END ....................C=10, degree=4, kernel=poly; total time=   0.6s
# [CV 3/5] END ....................C=10, degree=4, kernel=poly; total time=   3.3s
# [CV 4/5] END ....................C=10, degree=4, kernel=poly; total time=   0.7s
# [CV 5/5] END ....................C=10, degree=4, kernel=poly; total time=   8.9s
# [CV 1/5] END ...................C=100, degree=2, kernel=poly; total time=   0.0s
# [CV 2/5] END ...................C=100, degree=2, kernel=poly; total time=   0.0s
# [CV 3/5] END ...................C=100, degree=2, kernel=poly; total time=   0.0s
# [CV 4/5] END ...................C=100, degree=2, kernel=poly; total time=   0.0s
# [CV 5/5] END ...................C=100, degree=2, kernel=poly; total time=   0.1s
# [CV 1/5] END ...................C=100, degree=3, kernel=poly; total time=   6.6s
# [CV 2/5] END ...................C=100, degree=3, kernel=poly; total time=   0.4s
# [CV 3/5] END ...................C=100, degree=3, kernel=poly; total time=   1.8s
# [CV 4/5] END ...................C=100, degree=3, kernel=poly; total time=   0.0s
# [CV 5/5] END ...................C=100, degree=3, kernel=poly; total time=   0.1s
# [CV 1/5] END ...................C=100, degree=4, kernel=poly; total time=   1.3s
# [CV 2/5] END ...................C=100, degree=4, kernel=poly; total time=   4.0s
# [CV 3/5] END ...................C=100, degree=4, kernel=poly; total time=   5.3s
# [CV 4/5] END ...................C=100, degree=4, kernel=poly; total time=   2.5s
# [CV 5/5] END ...................C=100, degree=4, kernel=poly; total time=   9.0s
# [CV 1/5] END ..................C=1000, degree=2, kernel=poly; total time=   0.2s
# [CV 2/5] END ..................C=1000, degree=2, kernel=poly; total time=   0.1s
# [CV 3/5] END ..................C=1000, degree=2, kernel=poly; total time=   0.2s
# [CV 4/5] END ..................C=1000, degree=2, kernel=poly; total time=   0.2s
# [CV 5/5] END ..................C=1000, degree=2, kernel=poly; total time=   0.5s
# [CV 1/5] END ..................C=1000, degree=3, kernel=poly; total time=   4.0s
# [CV 2/5] END ..................C=1000, degree=3, kernel=poly; total time=   1.2s
# [CV 3/5] END ..................C=1000, degree=3, kernel=poly; total time=   2.4s
# [CV 4/5] END ..................C=1000, degree=3, kernel=poly; total time=   0.3s
# [CV 5/5] END ..................C=1000, degree=3, kernel=poly; total time=   2.7s
# [CV 1/5] END ..................C=1000, degree=4, kernel=poly; total time=   4.6s
# [CV 2/5] END ..................C=1000, degree=4, kernel=poly; total time=   6.0s
# [CV 3/5] END ..................C=1000, degree=4, kernel=poly; total time=  13.9s
# [CV 4/5] END ..................C=1000, degree=4, kernel=poly; total time=   3.3s
# [CV 5/5] END ..................C=1000, degree=4, kernel=poly; total time=   7.3s
# SVC(C=1000, kernel='linear')

# %%
print(svc_mod.best_params_)
# Out:
# {'C': 1000, 'kernel': 'linear'}

# %%
#Performance (Accuracy)
print('Accuracy (generalization)',svc_mod.score(X_test,y_test)) #Accuracy (generalization)  
print('Accuracy (memorization)',svc_mod.score(X_train,y_train)) #Accuracy (memorization)

#Comparing other metrics (f1_score)
print('F1_score (generalization)',f1_score(y_test,svc_mod.predict(X_test),average="weighted")) #F1_score (generalization)  
print('F1_score (memorization)',f1_score(y_train,svc_mod.predict(X_train),average="weighted")) #F1_score (memorization)
# Out:
# Accuracy (generalization) 0.8376156217882836
# Accuracy (memorization) 0.8492063492063492
# F1_score (generalization) 0.8283440719793268
# F1_score (memorization) 0.8409353564416044

# %%
srbf=SVC(C=100,kernel='rbf',gamma=0.1)
srbf.fit(X_train, y_train)
# Out:
# SVC(C=100, gamma=0.1)

# %%
#Performance (Accuracy)
print('Accuracy (generalization)',srbf.score(X_test,y_test)) #Accuracy (generalization)  
print('Accuracy (memorization)',srbf.score(X_train,y_train)) #Accuracy (memorization)

#Comparing other metrics (f1_score)
print('F1_score (generalization)',f1_score(y_test,srbf.predict(X_test),average="weighted")) #F1_score (generalization)  
print('F1_score (memorization)',f1_score(y_train,srbf.predict(X_train),average="weighted")) #F1_score (memorization)
# Out:
# Accuracy (generalization) 0.8221993833504625
# Accuracy (memorization) 0.8981481481481481
# F1_score (generalization) 0.8208254693083962
# F1_score (memorization) 0.8965172276036151

# %%
#Confusion Matrix
cf_matrix = confusion_matrix(y_train, srbf.predict(X_train))

sns.heatmap(cf_matrix, annot=True, annot_kws={"size": 12},cmap='Blues',fmt="d",xticklabels=names,yticklabels=names)

plt.show()
